# %%
import numpy as np

# %%
arr=np.array([1,2,3,4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
reshaped=arr.reshape(2,2)
reshaped
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
flattened=reshaped.flatten()
flattened
# Out:
# array([1, 2, 3, 4])

# %%
flattened=reshaped.flatten()
flattened[0]=36
flattened
# Out:
# array([36,  2,  3,  4])

# %%
arr
# Out:
# array([1, 2, 3, 4])

# %%
raveled=reshaped.ravel()
raveled[1]=88
raveled
# Out:
# array([ 1, 88,  3,  4])

# %%
arr
# Out:
# array([ 1, 88,  3,  4])

# %%
reshaped
# Out:
# array([[ 1, 88],
#        [ 3,  4]])

# %%
arr1=np.array([1,2,3])
print(arr1)
arr2=np.array([1,2,3])
print(arr2)
# Out:
# [1 2 3]
# [1 2 3]

# %%
arr1+arr2
# Out:
# array([2, 4, 6])

# %%
arr1+4
# Out:
# array([5, 6, 7])
